# %% [markdown]
# # Model Evaluation
#
# Evaluates the Accuracy, F1-Score, and Classification Report of our models using shared `eval_utils.py`.

# %%
import sys
import os
sys.path.append(os.path.abspath('../backend'))

import eval_utils
import numpy as np

# %%
# Mock data for testing the evaluation pipeline

# Simulating true and predicted labels for a classification task (e.g., distortion detection)
y_true = [0, 1, 2, 0, 1, 2, 0, 2, 1, 1]
y_pred = [0, 1, 1, 0, 1, 2, 0, 2, 0, 1]
target_names = ['No Distortion', 'Catastrophizing', 'Black-and-White']

metrics = eval_utils.evaluate_predictions(y_true, y_pred, target_names)
eval_utils.print_evaluation_report(metrics, 'Cognitive Distortion Model')
